# %% [markdown]
# # Testing the CNN model

# %%
from python_files.cnn import *

# %% [markdown]
# ## Confirmed cases in India

# %%
pred,_,figure = cnn_predict("confirmed","India")

# %%
# predictions for the following week
pred
# Out:
#          Date     Cases
# 0  30/12/2020  10264912
# 1  31/12/2020  10284123
# 2  01/01/2021  10302444
# 3  02/01/2021  10319368
# 4  03/01/2021  10334262
# 5  04/01/2021  10349002
# 6  05/01/2021  10364533

# %%
# graph
figure.show()

# %% [markdown]
# ## Deaths in US

# %%
pred,_,figure = cnn_predict("deaths","US")

# %%
# predictions for the following week
pred
# Out:
#          Date   Cases
# 0  30/12/2020  341749
# 1  31/12/2020  344491
# 2  01/01/2021  346482
# 3  02/01/2021  348030
# 4  03/01/2021  349184
# 5  04/01/2021  351197
# 6  05/01/2021  354518

# %%
# graph
figure.show()

# %% [markdown]
# ## Recoveries in Japan

# %%
pred,_,figure = cnn_predict("recovered","Japan")

# %%
# predictions for the following week
pred
# Out:
#          Date   Cases
# 0  30/12/2020  189204
# 1  31/12/2020  191791
# 2  01/01/2021  194482
# 3  02/01/2021  197045
# 4  03/01/2021  199497
# 5  04/01/2021  201776
# 6  05/01/2021  204097

# %%
# graph
figure.show()
